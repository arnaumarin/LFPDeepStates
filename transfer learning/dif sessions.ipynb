# %%
# we are not counting unknowns
ses_2_aw = [0.39,0.25,0.35,0.96,0.94,0.89,0.31,0.72,0.01]
ses_2_aw_unknown = [0.1,0.45,0.55,0.02,0.03,0.08,0.53,0.23,0.93]
ses_2_SO = [0.20,0.86,1,0.97,0.98,1,0.97,0.14,0.2]
ses_2_SO_unknown = [0.21,0.09,0,0.02,0.01,0,0.03,0.81,0.74]
ses_2_MA = [0.14, 0.83, 0.91,0.79,0.69,0.9,0.87,0.7,0.54]
ses_2_MA_unknown = [0.27,0.12,0.08,0.18,0.26,0.07,0.12,0.26,0.45]
data = [ses_2_aw, ses_2_aw_unknown, ses_2_SO, ses_2_SO_unknown, ses_2_MA, ses_2_MA_unknown]

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
import numpy as np

def plot_custom_boxplot(data_dict):
    """
    Create custom subplots for known and unknown data based on the input data dictionary.

    Args:
    - data_dict (dict): Dictionary containing data labels as keys and lists of values as values.

    Returns:
    - None. It displays the boxplots.
    """

    # Separate data into known and unknown based on labels
    known_labels = [label for label in data_dict if 'unknown' not in label]
    unknown_labels = [label for label in data_dict if 'unknown' in label]

    known_data = [data_dict[label] for label in known_labels]
    unknown_data = [data_dict[label] for label in unknown_labels]

    # Define colors
    known_colors = ['lightblue' for _ in known_labels]
    unknown_colors = ['grey' for _ in unknown_labels]

    fig, (ax1, ax2) = plt.subplots(nrows=2, figsize=(8, 10))

    # Plotting known data
    bp1 = ax1.boxplot(known_data, patch_artist=True, showfliers=False)
    for patch, color in zip(bp1['boxes'], known_colors):
        patch.set_facecolor(color)
    ax1.set_xticks(np.arange(1, len(known_labels) + 1))
    ax1.set_xticklabels(known_labels, rotation=45, ha='right', fontname='Arial')
    ax1.set_ylabel('Accuracy', fontname='Arial')

    # Plotting unknown data
    bp2 = ax2.boxplot(unknown_data, patch_artist=True, showfliers=False)
    for patch, color in zip(bp2['boxes'], unknown_colors):
        patch.set_facecolor(color)
    ax2.set_xticks(np.arange(1, len(unknown_labels) + 1))
    ax2.set_xticklabels(unknown_labels, rotation=45, ha='right', fontname='Arial')
    ax2.set_ylabel('Presence in percentage (%) after CNN models', fontname='Arial')

    # Common plot adjustments
    for ax in [ax1, ax2]:
        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        ax.spines['bottom'].set_visible(False)
        ax.spines['left'].set_visible(False)
        for label in ax.get_xticklabels() + ax.get_yticklabels():
            label.set_fontname('Arial')

    plt.tight_layout()
    plt.show()

# %%
ses_5_aw = [0.27,0.94,0.49,0.79,0.87,0.36,0.77]
ses_5_aw_unknown = [0.32,0.06,0.41,0.18,0.09,0.42,0.15]
ses_5_SO = [0.28,0.96,0.99,0.87,0.99,1,0.98]
ses_5_SO_unknown = [0.35,0.03,0.01,0.12,0.01,0,0.02]
ses_5_MA = [0.17,0.63,0.91,0.94,0.98,0.84,0.99]
ses_5_MA_unknown = [0.33,0.19,0.08,0.06,0.02,0.1,0.01]

# %%
ses_7_aw = [0.22, 0.84,0.66,0.91,0.83,0.7,0.85,0.91,0.73]
ses_7_aw_unknown = [0.18,0.13,0.19,0.05,0.1,0.22,0.11,0.07,0.17]
ses_7_SO = [0.7,0.81,0.99,0.98,0.96,1,0.99,0.97,0.91]
ses_7_SO_unknown = [0.15,0.1,0.01,0.01,0.03,0,0.01,0.03,0.07]
ses_7_MA = [1,0.86,0.95,0.96,0.98,0.92,0.33,0.76,0.96]
ses_7_MA_unknown = [0,0.09, 0.04,0.03,0.01,0.04,0.01,0.19,0.04]

# %%
data_input = {
    'ses_2_aw': ses_2_aw,
    'ses_5_aw': ses_5_aw,
    'ses_7_aw': ses_7_aw,

    'ses_2_SO': ses_2_SO,
    'ses_5_SO': ses_5_SO,
    'ses_7_SO': ses_7_SO,
    'ses_2_MA': ses_2_MA,
    'ses_5_MA': ses_5_MA,
    'ses_7_MA': ses_7_MA,

    'ses_2_aw_unknown': ses_2_aw_unknown,
    'ses_5_aw_unknown': ses_5_aw_unknown,
    'ses_7_aw_unknown': ses_7_aw_unknown,
    'ses_2_SO_unknown': ses_2_SO_unknown,
    'ses_5_SO_unknown': ses_5_SO_unknown,
    'ses_7_SO_unknown': ses_7_SO_unknown,
    'ses_2_MA_unknown': ses_2_MA_unknown,
    'ses_5_MA_unknown': ses_5_MA_unknown,
    'ses_7_MA_unknown': ses_7_MA_unknown
}
plot_custom_boxplot(data_input)

# %%
subjects_sessions = [('Phoebe', '210620'), ('Phoebe', '210717'),('Phoebe', '210626'),('Phoebe', '210725'),
                    ('Monica', '210724'),  ('Monica', '210731'), ('Monica', '210703'),
                    ('Natasha', '220107'),('Natasha', '211211'),
                    ('Skipper', '210123'),
('Omar', '180709'),  ('Smith', '210213'),('Stanford', '211205'), ('Stanford', '211228'), ('Smith', '210206'), ('Carrie', '210108')]

# %%
import random

def create_groups(num_groups, number_max_sessions_training, subjects_sessions):
    special_subjects = ['Monica', 'Skipper', 'Natasha', 'Phoebe']

    # Extract sessions for each subject for easy access
    sessions_per_subject = {}
    for subject, session in subjects_sessions:
        if subject not in sessions_per_subject:
            sessions_per_subject[subject] = []
        sessions_per_subject[subject].append(session)

    groups = []

    for _ in range(num_groups):
        # Step 3: Select one random subject from the special_subjects list
        chosen_special_subject = random.choice(special_subjects)

        # Step 4: Select one random session from the chosen special subject
        chosen_special_session = random.choice(sessions_per_subject[chosen_special_subject])

        # Exclude chosen subject for subsequent selections
        remaining_subjects = [subject for subject in sessions_per_subject if subject != chosen_special_subject]

        # Step 5: From the remaining subjects, select number_max_sessions_training sessions
        remaining_sessions = []
        for subject in remaining_subjects:
            remaining_sessions.extend([(subject, s) for s in sessions_per_subject[subject]])

        chosen_training_sessions = random.sample(remaining_sessions, min(number_max_sessions_training, len(remaining_sessions)))

        groups.append((chosen_special_subject, chosen_special_session, chosen_training_sessions))

    return groups
groups = create_groups(7, 7, subjects_sessions)
print(groups)
# Out:
# [('Phoebe', '210717', [('Natasha', '220107'), ('Smith', '210213'), ('Monica', '210703'), ('Stanford', '211228'), ('Skipper', '210123'), ('Monica', '210731'), ('Smith', '210206')]), ('Skipper', '210123', [('Phoebe', '210717'), ('Monica', '210731'), ('Smith', '210213'), ('Carrie', '210108'), ('Monica', '210703'), ('Stanford', '211205'), ('Natasha', '220107')]), ('Monica', '210724', [('Smith', '210213'), ('Natasha', '211211'), ('Phoebe', '210717'), ('Carrie', '210108'), ('Stanford', '211205'), ('Skipper', '210123'), ('Natasha', '220107')]), ('Phoebe', '210626', [('Smith', '210206'), ('Monica', '210724'), ('Monica', '210703'), ('Stanford', '211205'), ('Smith', '210213'), ('Skipper', '210123'), ('Carrie', '210108')]), ('Skipper', '210123', [('Monica', '210724'), ('Phoebe', '210725'), ('Smith', '210213'), ('Omar', '180709'), ('Monica', '210703'), ('Stanford', '211228'), ('Phoebe', '210626')]), ('Phoebe', '210620', [('Omar', '180709'), ('Monica', '210731'), ('Skipper', '210123'), ('Stanford
# ...

# %%
pairs_2ses = [
    ('Phoebe', '210626', [('Monica', '210724'),('Natasha', '211211')]),
    ('Skipper', '210123', [('Phoebe', '210626'),('Smith', '210213')]),
    ('Phoebe', '210725', [('Natasha', '211211'),('Carrie', '210108')]),
    ('Natasha', '220107', [('Phoebe', '210626'),('Phoebe', '210620')]),
    ('Monica', '210724', [('Phoebe', '210717'),('Smith', '210213')]),
    ('Monica', '210731', [('Smith', '210213'),('Phoebe', '210725')]),
    ('Phoebe', '210717', [('Carrie', '210108'),('Monica', '210703')])
]
pairs_5se = [
    ('Monica', '210724', [('Stanford', '211228'), ('Stanford', '211205'), ('Phoebe', '210725'), ('Smith', '210213'), ('Phoebe', '210626')]),
    ('Natasha', '211211', [('Skipper', '210123'), ('Carrie', '210108'), ('Phoebe', '210725'), ('Phoebe', '210626'), ('Smith', '210213')]),
    ('Monica', '210703', [('Natasha', '211211'), ('Carrie', '210108'), ('Smith', '210213'), ('Omar', '180709'), ('Smith', '210206')]),
    ('Phoebe', '210717', [('Stanford', '211228'), ('Natasha', '211211'), ('Carrie', '210108'), ('Monica', '210731'), ('Omar', '180709')]),
    ('Skipper', '210123', [('Monica', '210724'), ('Natasha', '220107'), ('Stanford', '211205'), ('Monica', '210703'), ('Smith', '210206')]),
    ('Skipper', '210123', [('Phoebe', '210717'), ('Phoebe', '210626'), ('Natasha', '211211'), ('Smith', '210206'), ('Phoebe', '210620')]),
    ('Natasha', '211211', [('Skipper', '210123'), ('Smith', '210206'), ('Monica', '210731'), ('Phoebe', '210620'), ('Stanford', '211228')])
]

pairs_7se = [
    ('Phoebe', '210717', [('Natasha', '220107'), ('Smith', '210213'), ('Monica', '210703'), ('Stanford', '211228'), ('Skipper', '210123'), ('Monica', '210731'), ('Smith', '210206')]),
    ('Skipper', '210123', [('Phoebe', '210717'), ('Monica', '210731'), ('Smith', '210213'), ('Carrie', '210108'), ('Monica', '210703'), ('Stanford', '211205'), ('Natasha', '220107')]),
    ('Monica', '210724', [('Smith', '210213'), ('Natasha', '211211'), ('Phoebe', '210717'), ('Carrie', '210108'), ('Stanford', '211205'), ('Skipper', '210123'), ('Natasha', '220107')]),
    ('Phoebe', '210626', [('Smith', '210206'), ('Monica', '210724'), ('Monica', '210703'), ('Stanford', '211205'), ('Smith', '210213'), ('Skipper', '210123'), ('Carrie', '210108')]),
    ('Skipper', '210123', [('Monica', '210724'), ('Phoebe', '210725'), ('Smith', '210213'), ('Omar', '180709'), ('Monica', '210703'), ('Stanford', '211228'), ('Phoebe', '210626')]),
    ('Phoebe', '210620', [('Omar', '180709'), ('Monica', '210731'), ('Skipper', '210123'), ('Stanford', '211228'), ('Natasha', '220107'), ('Smith', '210206'), ('Natasha', '211211')]),
    ('Monica', '210703', [('Phoebe', '210620'), ('Phoebe', '210717'), ('Smith', '210213'), ('Smith', '210206'), ('Skipper', '210123'), ('Stanford', '211228'), ('Natasha', '220107')])
]
